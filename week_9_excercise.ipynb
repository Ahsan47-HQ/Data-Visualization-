# %%
# Data Visualization
# Btech Computer Science Stream, January 2025
# Week 9 - String Manipulation and Data Wrangling
# Name: Mohammed Ahsan Bagsaria , 240968484 , Date:20/03/2025

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
se = pd.read_csv("sentiment.csv",index_col=0)
se
# Out:
#                                                   Text    Sentiment  \
# ID
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 728  Collaborating on a science project that receiv...       Happy
# 729  Attending a surprise birthday party organized ...       Happy
# 730  Successfully fundraising for a school charity ...       Happy
# 731  Participating in a multicultural festival, cel...       Happy
# 732  Organizing a virtual talent show during challe...       Happy
#
#             Timestamp                                   User     Platform  \
# ID
# 0    15-01-2023 12:30                          User123          Twitter
# ...

# %%
se.drop_duplicates(inplace=True)
se.dropna(subset = ['Sentiment','Text'],inplace=True)
se
# Out:
#                                                   Text    Sentiment  \
# ID
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 728  Collaborating on a science project that receiv...       Happy
# 729  Attending a surprise birthday party organized ...       Happy
# 730  Successfully fundraising for a school charity ...       Happy
# 731  Participating in a multicultural festival, cel...       Happy
# 732  Organizing a virtual talent show during challe...       Happy
#
#             Timestamp                                   User     Platform  \
# ID
# 0    15-01-2023 12:30                          User123          Twitter
# ...

# %%
# 1. In the sentiment feature and text, trim white spaces and convert to lowercase.
# se["Sentiment"] = se["Sentiment"].replace(se['Sentiment'].str.strip().str.lower(),inplace=True) - makes it None
# se = se.replace(se['Text'] , se["Text"].str.strip().str.lower(),inplace=True) - makes the dataframe None
se["Sentiment"] = se["Sentiment"].str.strip().str.lower()
se['Text'] = se['Text'].str.strip().str.lower()
display(se)
# Out:
#                                                   Text Sentiment  \
# ID
# 0                enjoying a beautiful day at the park!  positive
# 1                   traffic was terrible this morning.  negative
# 2                  just finished an amazing workout! 💪  positive
# 3          excited about the upcoming weekend getaway!  positive
# 4          trying out a new recipe for dinner tonight.   neutral
# ..                                                 ...       ...
# 728  collaborating on a science project that receiv...     happy
# 729  attending a surprise birthday party organized ...     happy
# 730  successfully fundraising for a school charity ...     happy
# 731  participating in a multicultural festival, cel...     happy
# 732  organizing a virtual talent show during challe...     happy
#
#             Timestamp                                   User     Platform  \
# ID
# 0    15-01-2023 12:30                          User123          Twitter
# ...

# %%
# 2. What are the sentiment categories? Tabulate and visualize the number of texts for each category 
print("The Sentiment categories are:\n", se['Sentiment'].value_counts())
se_ = se.groupby("Sentiment")[["Text"]].nunique() # The column 'Text' now holds the count of texts , nunique is similar to count , but takes only unique
print("The number of texts for each category:")
se_ = se_.sort_values(by='Text',ascending=False)
display(se_)
plt.figure(figsize = (22,13))
sns.barplot(data = se_.reset_index(), x='Sentiment',y='Text',palette = 'viridis',legend=False, hue = 'Sentiment') # countplot can also be used
# .reset_index is to convert the groupby object (with an aggregated function) to a dataframe
plt.title("Count of Text grouped by sentiments")
plt.xlabel("Sentiments")
plt.ylabel("Count of Texts")
plt.xticks(rotation=90)
plt.show()
# Out:
# The Sentiment categories are:
#  Sentiment
# positive       45
# joy            44
# excitement     37
# neutral        18
# contentment    18
#                ..
# suffering       1
# marvel          1
# spark           1
# immersion       1
# intrigue        1
# Name: count, Length: 191, dtype: int64
# The number of texts for each category:
#                   Text
# Sentiment
# positive            45
# joy                 44
# excitement          37
# contentment         18
# neutral             18
# ...                ...
# mindfulness          1
# mesmerizing          1
# melodic              1
# marvel               1
# celestial wonder     1
#
# [191 rows x 1 columns]

# %%
# 3. Tabulate and Visualize the text length for each sentiment category.
se["Text_length"]=se["Text"].apply(len)
se_1 = se.groupby('Sentiment')[['Text_length']].mean()
se_1 = se_1.sort_values(by='Text_length',ascending=False)
print('The text length (mean) for each sentiment category is: ')
display(se_1)
se_1 = se_1.reset_index()
plt.figure(figsize=(22,13))
sns.barplot(data = se_1 , x = 'Sentiment' , hue = 'Sentiment', y= 'Text_length',legend=False, palette = 'viridis')
plt.title('Text Length for each sentiment category')
plt.xlabel('Sentiments')
plt.ylabel('Mean Text Length')
plt.xticks(rotation=90)
plt.show()
# Out:
# The text length (mean) for each sentiment category is:
#                       Text_length
# Sentiment
# winter magic           155.000000
# whispers of the past   150.000000
# thrilling journey      148.000000
# celestial wonder       147.000000
# ocean's freedom        145.000000
# ...                           ...
# anger                   47.500000
# intimidation            47.500000
# resentment              45.333333
# positive                40.133333
# negative                38.250000
#
# [191 rows x 1 columns]

# %%
# 4. Find and display the text(s) with the maximum number of likes.
display(se[se['Likes']==se['Likes'].max()][['Text','Likes']])
# Out:
#                                                   Text  Likes
# ID
# 336  thrilled to witness the grandeur of a cultural...     80
# 346  motivated to achieve fitness goals after an in...     80
# 356  anticipation for an upcoming adventure in an e...     80
# 369  elation over discovering a rare book in a quai...     80
# 383  a sense of wonder at the vastness of the cosmo...     80
# 403  awe-inspired by the vastness of the cosmos on ...     80
# 433  heartache deepens, a solitary journey through ...     80
# 471  dancing on sunshine, each step a celebration o...     80
# 482  surrounded by the colors of joy, a canvas pain...     80
# 511  at the front row of adele's concert, each note...     80
# 521  at a justin bieber concert, the infectious bea...     80
# 531  captivated by the spellbinding plot twists, th...     80
# 541  celebrating a historic victory in the world cu...     80
# 551  after a series of defeats, the soccer team fac...     80
# ...

# %%
# 5. Find and display the text(s) with the maximum reposts. what is its sentiment?
display(se[se['Retweets']==se['Retweets'].max()][['Text','Retweets','Sentiment']])
# Out:
#                                                   Text  Retweets  \
# ID
# 336  thrilled to witness the grandeur of a cultural...        40
# 346  motivated to achieve fitness goals after an in...        40
# 356  anticipation for an upcoming adventure in an e...        40
# 369  elation over discovering a rare book in a quai...        40
# 383  a sense of wonder at the vastness of the cosmo...        40
# 403  awe-inspired by the vastness of the cosmos on ...        40
# 433  heartache deepens, a solitary journey through ...        40
# 471  dancing on sunshine, each step a celebration o...        40
# 482  surrounded by the colors of joy, a canvas pain...        40
# 511  at the front row of adele's concert, each note...        40
# 521  at a justin bieber concert, the infectious bea...        40
# 531  captivated by the spellbinding plot twists, th...        40
# 541  celebrating a historic victory in the world cu...        40
# ...

# %%
# 6. Tabulate and Visualize the top 5 countries that have posted the most texts with a positive sentiment.
se['Country'] = se['Country'].str.strip()
top_5 = se[se['Sentiment']=='positive'].groupby('Country')['Text'].count().reset_index()
top_5 = top_5.sort_values(by='Text',ascending =False).head(5)
display(top_5)
sns.barplot(data = top_5, x='Country',y='Text',hue='Country',legend=False,palette='Greens_r')
plt.title("Top 5 countries with the highest amount of positive texts",fontsize=13)
plt.xlabel('Countries')
plt.ylabel('Number of positive texts')
plt.show()
# Out:
#      Country  Text
# 4        USA    18
# 3         UK    10
# 1     Canada     8
# 2      India     7
# 0  Australia     2

# %%
# 7. Find and display all the text(s) with the word ‘Travel’ in their hashtag.
hashes = se[se['Hashtags'].str.contains('Travel')][['Text','Hashtags']]
display(hashes)
# Out:
#                                                   Text  \
# ID
# 3          excited about the upcoming weekend getaway!
# 73   excitement building up for the upcoming vacation!
# 85   enjoying every moment of this trip—pure enjoym...
# 146  arousal of excitement before a much-awaited trip.
# 597  spontaneously booked a weekend getaway. advent...
# 611  embarked on a road trip to revisit cherished p...
# 623  embarked on a solo travel adventure, discoveri...
#
#                                             Hashtags
# ID
# 3          #Travel #Adventure
# 73       #Excitement #TravelPlans
# 85     #Enjoyment #Travel
# 146   #Arousal #TravelAdventure
# 597                       #GetawayGoals #TeenTravel
# 611                  #CherishedPlaces #SeniorTravel
# 623                #DiscoverNewPlaces #SeniorTravel

# %%
# 8. Find and display the most popular (most number of likes) posts (top 5) 
# from the year 2020 which were of a negative sentiment.
pops = se[(se['Sentiment']=='negative') & (se['Year']==2020)][['Text','Likes']]
pops = pops.sort_values(by = 'Likes',ascending=False).head(5)
pops
# Out:
# Empty DataFrame
# Columns: [Text, Likes]
# Index: []

# %%
# 9. Find and display a list of Users and their posts whose texts are labeled ‘Happiness’ sentiment.
happy = se[se['Sentiment']=='happiness'][['User','Text']]
happy
# Out:
#                      User                                               Text
# ID
# 57       ProudFriend       pure happiness: celebrating a loved one's achi...
# 81       NewParentJoy      overflowing happiness: welcoming a new family ...
# 368   SunnyDayEnthusiast   happiness blooms like flowers in a garden on a...
# 472       EchoedLaughter   laughter echoes in the air, a chorus of happin...
# 489     LaughterSymphony   a symphony of laughter, each note a key to unl...

# %%
# 10. Tabulate and visualize the years and countrywide tweets of the sentiments. Pick tweets
# with sentiments, ‘Positive,’ ‘Negative,’ and ‘Neutral’ only.
# s5 = s5.groupby(['Year','Country','Sentiment']).size().reset_index(name='Tweet_count') - can also be used
s5 = se[se['Sentiment'].isin(['negative','positive','neutral'])][['Year','Country','Sentiment','Text']]
display(s5)
# Thus, we can see that only for the year 2023, these sentiments were noted
req = s5.groupby('Country')[['Text','Sentiment']].count().reset_index()
req.rename(columns={'Text': 'Tweet_count'}, inplace=True)
display(req)
plt.figure(figsize = (19,12))
sns.barplot(data = req.sort_values(by='Tweet_count',ascending=False), x='Country',y= 'Tweet_count',
            hue='Country',palette = 'Blues_r',errorbar=None,legend=False)
plt.title("Country vs. Number of Texts")
plt.xlabel('Country')
plt.ylabel('Number of Texts')
plt.show()

se_f = s5.groupby(['Country','Sentiment'])['Text'].count().reset_index(name='Tweet_count')
heatmap_data = se_f.pivot(index='Country', columns='Sentiment', values='Tweet_count').fillna(0)

plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, cmap='coolwarm', annot=True, fmt=".0f", linewidths=0.5)

plt.xlabel("Sentiment")
plt.ylabel("Country")
plt.title("Sentiment Distribution Across Countries")
plt.show()
# Out:
#      Year    Country Sentiment  \
# ID
# 0    2023        USA  positive
# 1    2023     Canada  negative
# 2    2023        USA  positive
# 3    2023         UK  positive
# 4    2023  Australia   neutral
# ..    ...        ...       ...
# 714  2023        USA   neutral
# 715  2023     Canada   neutral
# 716  2023         UK   neutral
# 717  2023        USA   neutral
# 718  2023     Canada   neutral
#
#                                                   Text
# ID
# 0                enjoying a beautiful day at the park!
# 1                   traffic was terrible this morning.
# 2                  just finished an amazing workout! 💪
# 3          excited about the upcoming weekend getaway!
# 4          trying out a new recipe for dinner tonight.
# ..                                                 ...
# 714  participating in a science fair to showcase a ...
# 715  attending a workshop on time management to enh...
# 716  volunteering at a local charity event to give ...
# ...
